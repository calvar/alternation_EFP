# %%
import numpy as np

from pprint import pprint
from pyvis.network import Network

import sys

sys.path.append('../src')

from config.config import PATHS

from graphs.best_graph_creator import GraphCreator
from graphs.graph_display import GraphVisualizer

# %% [markdown]
# ### Initialize parameters

# %%
N = 15
s = 4

# %% [markdown]
# ### Create the optimal graph

# %%
graph = GraphCreator(N, s)
graph.build_graph()

output_path = graph.save_to_json()
print(f"Graph saved to: {output_path}")
# Out:
# Graph saved to: /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/notebooks/../data/graphs/graph_data_N15s4.json

# %% [markdown]
# ### Visualize the dependencies' graphs

# %%
gv = GraphVisualizer(
    num_nodes=N,
    num_steps=s,
)

nets, output_files = gv.generate_all_patterns(width="600px", height="600px", physics=True)

for i in range(len(nets)):
    nets[i].show(str(output_files[i]), notebook=False)
# Out:
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N15s4_pattern0.html
