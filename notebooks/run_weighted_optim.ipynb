# %%
import numpy as np

from pprint import pprint
from pyvis.network import Network

import sys

sys.path.append('../src')

from config.config import PATHS

from graphs.best_weighted_graph_creator import WeightedGraphCreator
from graphs.graph_display import GraphVisualizer

# %% [markdown]
# ### Initialize parameters

# %%
procs = {0:2, 1:1, 2:3, 3:1, 4:2, 5:1}
b = 3

# %%
graph = WeightedGraphCreator(procs, b)
graph.build_graph()

output_path = graph.save_to_json()
print(f"Graph saved to: {output_path}")
# Out:
# Graph saved to: /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/notebooks/../data/graphs/graph_data_N12s3.json
