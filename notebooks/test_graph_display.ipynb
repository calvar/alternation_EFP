# %%
import numpy as np
import ipywidgets as widgets
from IPython.display import display, clear_output
from pyvis.network import Network

import sys

sys.path.append('../src')

from config.config import PATHS
from graphs.graph_display import GraphVisualizer

# %%
N = 12
s = 4
gv = GraphVisualizer(
    num_nodes=N,
    num_steps=s,
)

# %%
nets, output_files = gv.generate_all_patterns(width="600px", height="600px", physics=True)

# %%
for i in range(len(nets)):
    nets[i].show(str(output_files[i]), notebook=False)
# Out:
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern0.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern1.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern2.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern3.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern4.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern5.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern6.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern7.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern8.html
# /home/carlos/Documents/InformationT/edgar_german/alternation_EFP/data/html/graph_N12s4_pattern9.html
