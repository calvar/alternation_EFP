# %%
import numpy as np
import ipywidgets as widgets
from IPython.display import display, clear_output
from pyvis.network import Network

import sys

sys.path.append('../src')

from config.config import PATHS
from graphs.graph_display import GraphVisualizer

# %%
gv = GraphVisualizer(
    num_nodes=6,
    num_steps=2,
)

# %%
nets, output_files = gv.generate_all_patterns(width="600px", height="600px", physics=True)

# %%
for i in range(len(nets)):
    nets[i].show(str(output_files[i]), notebook=False)
# Out:
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern0.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern1.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern2.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern3.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern4.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern5.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern6.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern7.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern8.html
# /home/carlos/Documents/Information/edgar_german/repo/alternation_EFP/data/html/graph_N6s2_pattern9.html
