# %%
import numpy as np

import sys

sys.path.append('../src')

from config.config import PATHS
from graphs.cycle_analyzer import CycleAnalyzer

# %%
ca = CycleAnalyzer(
    num_nodes=6,
    num_steps=2,
)

# %%
ca.process()
# Out:
# Pattern 0:
# Cycle 0: 1 ones, Pattern: 5 -> 0 -> 3
# Pattern 1:
# Cycle 0: 1 ones, Pattern: 2 -> 4 -> 1
# Pattern 2:
# Cycle 0: 1 ones, Pattern: 2 -> 0 -> 4
# Pattern 3:
# Cycle 0: 1 ones, Pattern: 2 -> 5 -> 3
# Pattern 4:
# Cycle 0: 1 ones, Pattern: 5 -> 0 -> 3
# Pattern 5:
# Cycle 0: 1 ones, Pattern: 2 -> 3 -> 1
# Pattern 6:
# Cycle 0: 1 ones, Pattern: 5 -> 4 -> 3
# Pattern 7:
# Cycle 0: 1 ones, Pattern: 2 -> 3 -> 5
# Pattern 8:
# Cycle 0: 1 ones, Pattern: 1 -> 3 -> 0
# Pattern 9:
# Cycle 0: 1 ones, Pattern: 2 -> 0 -> 3
